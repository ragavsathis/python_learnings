# %% [markdown]
# # This script is used to fetch package analytics data from https://formulae.brew.sh/

# %%
import requests
import json

# This is the url from where we can fetch different package name 
get_package_url = 'https://formulae.brew.sh/api/formula.json'

# Use requests api to get the contents from the json 
package_res = requests.get(get_package_url)

# sample printout of one package and can identify different fields on the package structure.
package = package_res.json()[0]
package
print(f"{package['name']} description - {package['desc']}")
# Out:
# a2ps description - Any-to-PostScript filter

# %% [markdown]
# ## Get analytics data of one package

# %%
# PACKAGE contains structure of one package
pkg_name = package['name']
pkg_desc = package['desc']

# Constrcution of package url for fetching the analytics data
pkg_json_url = f'https://formulae.brew.sh/api/formula/{pkg_name}.json'
pkg_res = requests.get(pkg_json_url)
pkg_res_data = pkg_res.json()

# Retreiving the analytics data from the json retreived from the package url
pkg_analytics_30d = pkg_res_data['analytics']['install_on_request']['30d'][pkg_name]
pkg_analytics_90d = pkg_res_data['analytics']['install_on_request']['90d'][pkg_name]
pkg_analytics_365d = pkg_res_data['analytics']['install_on_request']['365d'][pkg_name]

print(f'{pkg_name} analytics data for 30d-{pkg_analytics_30d}, 90d-{pkg_analytics_90d}, 365d-{pkg_analytics_365d}')
# Out:
# a2ps analytics data for 30d-82, 90d-324, 365d-1145

# %% [markdown]
# ## get the data from all the packages

# %%
import time
pkg_data = list()

# use start time to calculte the time taken for retreival of all analytics data
start_time = time.perf_counter()

for pkg in package_res.json():
    pkg_dict = dict()
    pkg_dict['pkg_name'] = pkg['name']
    pkg_dict['description'] = pkg['desc']
    
    pkg_url = f'https://formulae.brew.sh/api/formula/{pkg_dict["pkg_name"]}.json'
    pkg_res = requests.get(pkg_url)
    pkg_res_data = pkg_res.json()

    # Retreiving the analytics data from the json retreived from the package url
    pkg_dict['analytics_30d'] = pkg_res_data['analytics']['install_on_request']['30d'][pkg_dict['pkg_name']]
    pkg_dict['analytics_90d'] = pkg_res_data['analytics']['install_on_request']['90d'][pkg_dict['pkg_name']]
    pkg_dict['analytics_365d'] = pkg_res_data['analytics']['install_on_request']['365d'][pkg_dict['pkg_name']]
    pkg_data.append(pkg_dict)

end_time = time.perf_counter()
print(f'Total time took for fetching analytics data of all packages - {end_time - start_time} seconds')
# Out:
# Total time took for fetching analytics data of all packages - 890.3446401000001 seconds

# %%
print(json.dumps(pkg_data, indent=2))
# Out:
# [
#   {
#     "pkg_name": "a2ps",
#     "description": "Any-to-PostScript filter",
#     "analytics_30d": 82,
#     "analytics_90d": 324,
#     "analytics_365d": 1145
#   },
#   {
#     "pkg_name": "a52dec",
#     "description": "Library for decoding ATSC A/52 streams (AKA 'AC-3')",
#     "analytics_30d": 20,
#     "analytics_90d": 85,
#     "analytics_365d": 346
#   },
#   {
#     "pkg_name": "aacgain",
#     "description": "AAC-supporting version of mp3gain",
#     "analytics_30d": 54,
#     "analytics_90d": 149,
#     "analytics_365d": 557
#   },
#   {
#     "pkg_name": "aalib",
#     "description": "Portable ASCII art graphics library",
#     "analytics_30d": 60,
#     "analytics_90d": 197,
#     "analytics_365d": 867
#   },
#   {
#     "pkg_name": "aamath",
#     "description": "Renders mathematical expressions as ASCII art",
#     "analytics_30d": 17,
#     "analytics_90d": 59,
#     "analytics_365d": 221
#   },
#   {
#     "pkg_name": "aardvark_shell_utils",
#     "description": "Utilities to aid shell scripts or command-line users",
#     "analytics_30d": 8,
#     "analytics_90d": 33,
#     "analytics_365d": 118
#   },
#   {
#     "pkg_name": "abcde",
#     "description": "Better CD Encoder",
#     "analytics_30d": 41,
#     "analytics_90d": 145,
#     "analytics_365d": 670
#   },
#   {
#     "pkg_name": "abcl",
#     "description": "Armed Bear Common Lisp: a full implementation of Common Lisp",
#     "analytics_30d": 13,
#     "analytics_90d": 41,
#     "analytics_365d": 208
#   },
#   {
#     "pkg_name": "abcm2ps",
#     "description": "ABC music notation software",
#     "analytics_30d": 32,
#     "analytics_90d": 107,
#     "analytics_365d": 396
#   },
#   {
#     "pkg_name": "abcmidi",
#     "description": "Converts abc music notation files to MIDI files",
#     "analytics_30d": 68,
#     "analytics_90d": 188,
#     "analytics_365d": 654
#   },
#   {
#     "pkg_name": "abduco",
#     "description": "Provides session management: i.e. separate programs from terminals",
#     "analytics_30d": 8,
#     "analytics_90d": 39,
#     "analytics_365d": 180
#   },
#   {
#     "pkg_name": "abnfgen",
#     "description": "Quickly generate random documents that match an ABFN grammar",
#     "analytics_30d": 2,
#     "analytics_90d": 10,
#     "analytics_365d": 50
#   },
#   {
#     "pkg_name": "abook",
#     "description": "Address book with mutt support",
#     "analytics_30d": 37,
#     "analytics_90d": 98,
#     "analytics_365d": 394
#   },
#   {
#     "pkg_name": "abseil",
#     "description": "C++ Common Libraries",
#     "analytics_30d": 27,
#     "analytics_90d": 51,
#     "analytics_365d": 51
#   },
#   {
#     "pkg_name": "abuse",
#     "description": "Dark 2D side-scrolling platform game",
#     "analytics_30d": 27,
#     "analytics_90d": 98,
#     "analytics_365d": 392
#   },
#   {
#     "pkg_name": "abyss",
#     "description": "Genome sequence assembler for short reads",
#     "analytics_30d": 44,
#     "analytics_90d": 147,
#     "analytics_365d": 668
#   },
#   {
#     "pkg_name": "ace",
#     "description": "ADAPTIVE Communication Environment: OO network programming in C++",
#     "analytics_30d": 37,
#     "analytics_90d": 192,
#     "analytics_365d": 721
#   },
#   {
#     "pkg_name": "aces_container",
#     "description": "Reference implementation of SMPTE ST2065-4",
#     "analytics_30d": 9,
#     "analytics_90d": 32,
#     "analytics_365d": 129
#   },
#   {
#     "pkg_name": "ack",
#     "description": "Search tool like grep, but optimized for programmers",
#     "analytics_30d": 5133,
#     "analytics_90d": 20240,
#     "analytics_365d": 103325
#   },
#   {
#     "pkg_name": "acme",
#     "description": "Crossassembler for multiple environments",
#     "analytics_30d": 919,
#     "analytics_90d": 2689,
#     "analytics_365d": 10092
#   },
#   {
#     "pkg_name": "acmetool",
#     "description": "Automatic certificate acquisition tool for ACME (Let's Encrypt)",
#     "analytics_30d": 21,
#     "analytics_90d": 52,
#     "analytics_365d": 197
#   },
#   {
#     "pkg_name": "acpica",
#     "description": "OS-independent implementation of the ACPI specification",
#     "analytics_30d": 125,
#     "analytics_90d": 339,
#     "analytics_365d": 1135
#   },
#   {
#     "pkg_name": "activemq",
#     "description": "Apache ActiveMQ: powerful open source messaging server",
#     "analytics_30d": 1213,
#     "analytics_90d": 3101,
#     "analytics_365d": 10653
#   },
#   {
#     "pkg_name": "activemq-cpp",
#     "description": "C++ API for message brokers such as Apache ActiveMQ",
#     "analytics_30d": 9,
#     "analytics_90d": 30,
#     "analytics_365d": 196
#   },
#   {
#     "pkg_name": "adios2",
#     "description": "Next generation of ADIOS developed in the Exascale Computing Program",
#     "analytics_30d": 10,
#     "analytics_90d": 71,
#     "analytics_365d": 140
#   },
#   {
#     "pkg_name": "admesh",
#     "description": "Processes triangulated solid meshes",
#     "analytics_30d": 9,
#     "analytics_90d": 23,
#     "analytics_365d": 102
#   },
#   {
#     "pkg_name": "adns",
#     "description": "C/C++ resolver library and DNS resolver utilities",
#     "analytics_30d": 195,
#     "analytics_90d": 616,
#     "analytics_365d": 3105
#   },
#   {
#     "pkg_name": "adplug",
#     "description": "Free, hardware independent AdLib sound player library",
#     "analytics_30d": 3,
#     "analytics_90d": 15,
#     "analytics_365d": 54
#   },
#   {
#     "pkg_name": "adr-tools",
#     "description": "CLI tool for working with Architecture Decision Records",
#     "analytics_30d": 336,
#     "analytics_90d": 950,
#     "analytics_365d": 3468
#   },
#   {
#     "pkg_name": "advancecomp",
#     "description": "Recompression utilities for .PNG, .MNG, .ZIP, and .GZ files",
#     "analytics_30d": 134,
#     "analytics_90d": 374,
#     "analytics_365d": 1425
#   },
#   {
#     "pkg_name": "advancemame",
#     "description": "MAME with advanced video support",
#     "analytics_30d": 26,
#     "analytics_90d": 59,
#     "analytics_365d": 211
#   },
#   {
#     "pkg_name": "advancemenu",
#     "description": "Frontend for AdvanceMAME/MESS",
#     "analytics_30d": 13,
#     "analytics_90d": 20,
#     "analytics_365d": 52
#   },
#   {
#     "pkg_name": "advancescan",
#     "description": "Rom manager for AdvanceMAME/MESS",
#     "analytics_30d": 7,
#     "analytics_90d": 16,
#     "analytics_365d": 66
#   },
#   {
#     "pkg_name": "adwaita-icon-theme",
#     "description": "Icons for the GNOME project",
#     "analytics_30d": 1480,
#     "analytics_90d": 3518,
#     "analytics_365d": 11709
#   },
#   {
#     "pkg_name": "aescrypt",
#     "description": "Program for encryption/decryption",
#     "analytics_30d": 49,
#     "analytics_90d": 117,
#     "analytics_365d": 538
#   },
#   {
#     "pkg_name": "aescrypt-packetizer",
#     "description": "Encrypt and decrypt using 256-bit AES encryption",
#     "analytics_30d": 9,
#     "analytics_90d": 37,
#     "analytics_365d": 180
#   },
#   {
#     "pkg_name": "aespipe",
#     "description": "AES encryption or decryption for pipes",
#     "analytics_30d": 17,
#     "analytics_90d": 47,
#     "analytics_365d": 184
#   },
#   {
#     "pkg_name": "afflib",
#     "description": "Advanced Forensic Format",
#     "analytics_30d": 141,
#     "analytics_90d": 228,
#     "analytics_365d": 998
#   },
#   {
#     "pkg_name": "afio",
#     "description": "Creates cpio-format archives",
#     "analytics_30d": 2,
#     "analytics_90d": 11,
#     "analytics_365d": 243
#   },
#   {
#     "pkg_name": "afl-fuzz",
#     "description": "American fuzzy lop: Security-oriented fuzzer",
#     "analytics_30d": 59,
#     "analytics_90d": 215,
#     "analytics_365d": 1547
#   },
#   {
#     "pkg_name": "afsctool",
#     "description": "Utility for manipulating HFS+ compressed files",
#     "analytics_30d": 41,
#     "analytics_90d": 146,
#     "analytics_365d": 624
#   },
#   {
#     "pkg_name": "aften",
#     "description": "Audio encoder which generates ATSC A/52 compressed audio streams",
#     "analytics_30d": 28,
#     "analytics_90d": 45,
#     "analytics_365d": 171
#   },
#   {
#     "pkg_name": "afuse",
#     "description": "Automounting file system implemented in userspace with FUSE",
#     "analytics_30d": 7,
#     "analytics_90d": 26,
#     "analytics_365d": 114
#   },
#   {
#     "pkg_name": "agda",
#     "description": "Dependently typed functional programming language",
#     "analytics_30d": 279,
#     "analytics_90d": 695,
#     "analytics_365d": 2331
#   },
#   {
#     "pkg_name": "agedu",
#     "description": "Unix utility for tracking down wasted disk space",
#     "analytics_30d": 36,
#     "analytics_90d": 145,
#     "analytics_365d": 413
#   },
#   {
#     "pkg_name": "aggregate",
#     "description": "Optimizes lists of prefixes to reduce list lengths",
#     "analytics_30d": 6,
#     "analytics_90d": 26,
#     "analytics_365d": 121
#   },
#   {
#     "pkg_name": "aha",
#     "description": "ANSI HTML adapter",
#     "analytics_30d": 53,
#     "analytics_90d": 167,
#     "analytics_365d": 686
#   },
#   {
#     "pkg_name": "ahcpd",
#     "description": "Autoconfiguration protocol for IPv6 and IPv6/IPv4 networks",
#     "analytics_30d": 10,
#     "analytics_90d": 22,
#     "analytics_365d": 67
#   },
#   {
#     "pkg_name": "ahoy",
#     "description": "Creates self documenting CLI programs from commands in YAML files",
#     "analytics_30d": 42,
#     "analytics_90d": 122,
#     "analytics_365d": 495
#   },
#   {
#     "pkg_name": "aide",
#     "description": "File and directory integrity checker",
#     "analytics_30d": 17,
#     "analytics_90d": 58,
#     "analytics_365d": 259
#   },
#   {
#     "pkg_name": "aircrack-ng",
#     "description": "Next-generation aircrack with lots of new features",
#     "analytics_30d": 4226,
#     "analytics_90d": 12632,
#     "analytics_365d": 40601
#   },
#   {
#     "pkg_name": "airspy",
#     "description": "The usemode driver and associated tools for airspy",
#     "analytics_30d": 29,
#     "analytics_90d": 85,
#     "analytics_365d": 370
#   },
#   {
#     "pkg_name": "akamai",
#     "description": "CLI toolkit for working with Akamai's APIs",
#     "analytics_30d": 244,
#     "analytics_90d": 952,
#     "analytics_365d": 3020
#   },
#   {
#     "pkg_name": "akka",
#     "description": "Toolkit for building concurrent, distributed, and fault tolerant apps",
#     "analytics_30d": 36,
#     "analytics_90d": 181,
#     "analytics_365d": 595
#   },
#   {
#     "pkg_name": "alac",
#     "description": "Basic decoder for Apple Lossless Audio Codec files (ALAC)",
#     "analytics_30d": 10,
#     "analytics_90d": 32,
#     "analytics_365d": 129
#   },
#   {
#     "pkg_name": "aldo",
#     "description": "Morse code learning tool released under GPL",
#     "analytics_30d": 8,
#     "analytics_90d": 21,
#     "analytics_365d": 105
#   },
#   {
#     "pkg_name": "alexjs",
#     "description": "Catch insensitive, inconsiderate writing",
#     "analytics_30d": 9,
#     "analytics_90d": 85,
#     "analytics_365d": 332
#   },
#   {
#     "pkg_name": "algernon",
#     "description": "Pure Go web server with Lua, Markdown, HTTP/2 and template support",
#     "analytics_30d": 53,
#     "analytics_90d": 77,
#     "analytics_365d": 257
#   },
#   {
#     "pkg_name": "algol68g",
#     "description": "Algol 68 compiler-interpreter",
#     "analytics_30d": 3524,
#     "analytics_90d": 10265,
#     "analytics_365d": 38238
#   },
#   {
#     "pkg_name": "align",
#     "description": "Text column alignment filter",
#     "analytics_30d": 4,
#     "analytics_90d": 23,
#     "analytics_365d": 109
#   },
#   {
#     "pkg_name": "aliyun-cli",
#     "description": "Universal Command-Line Interface for Alibaba Cloud",
#     "analytics_30d": 212,
#     "analytics_90d": 867,
#     "analytics_365d": 2870
#   },
#   {
#     "pkg_name": "allegro",
#     "description": "C/C++ multimedia library for cross-platform game development",
#     "analytics_30d": 154,
#     "analytics_90d": 510,
#     "analytics_365d": 1634
#   },
#   {
#     "pkg_name": "allure",
#     "description": "Flexible lightweight test report tool",
#     "analytics_30d": 1606,
#     "analytics_90d": 4819,
#     "analytics_365d": 16051
#   },
#   {
#     "pkg_name": "allureofthestars",
#     "description": "Near-future Sci-Fi roguelike and tactical squad combat game",
#     "analytics_30d": 12,
#     "analytics_90d": 41,
#     "analytics_365d": 289
#   },
#   {
#     "pkg_name": "alluxio",
#     "description": "Open Source Memory Speed Virtual Distributed Storage",
#     "analytics_30d": 19,
#     "analytics_90d": 59,
#     "analytics_365d": 274
#   },
#   {
#     "pkg_name": "alot",
#     "description": "Text mode MUA using notmuch mail",
#     "analytics_30d": 11,
#     "analytics_90d": 111,
#     "analytics_365d": 568
#   },
#   {
#     "pkg_name": "alp",
#     "description": "Access Log Profiler",
#     "analytics_30d": 6,
#     "analytics_90d": 37,
#     "analytics_365d": 137
#   },
#   {
#     "pkg_name": "alpine",
#     "description": "News and email agent",
#     "analytics_30d": 231,
#     "analytics_90d": 1119,
#     "analytics_365d": 3439
#   },
#   {
#     "pkg_name": "alure",
#     "description": "Manage common tasks with OpenAL applications",
#     "analytics_30d": 27,
#     "analytics_90d": 88,
#     "analytics_365d": 265
#   },
#   {
#     "pkg_name": "amap",
#     "description": "Perform application protocol detection",
#     "analytics_30d": 30,
#     "analytics_90d": 79,
#     "analytics_365d": 465
#   },
#   {
#     "pkg_name": "amazon-ecs-cli",
#     "description": "CLI for Amazon ECS to manage clusters and tasks for development",
#     "analytics_30d": 564,
#     "analytics_90d": 1912,
#     "analytics_365d": 9989
#   },
#   {
#     "pkg_name": "amdatu-bootstrap",
#     "description": "Bootstrapping OSGi development",
#     "analytics_30d": 6,
#     "analytics_90d": 10,
#     "analytics_365d": 61
#   },
#   {
#     "pkg_name": "ammonite-repl",
#     "description": "Ammonite is a cleanroom re-implementation of the Scala REPL",
#     "analytics_30d": 506,
#     "analytics_90d": 2462,
#     "analytics_365d": 13272
#   },
#   {
#     "pkg_name": "ampl-mp",
#     "description": "The AMPL modeling language solver library",
#     "analytics_30d": 2,
#     "analytics_90d": 16,
#     "analytics_365d": 100
#   },
#   {
#     "pkg_name": "amqp-cpp",
#     "description": "C++ library for communicating with a RabbitMQ message broker",
#     "analytics_30d": 31,
#     "analytics_90d": 94,
#     "analytics_365d": 338
#   },
#   {
#     "pkg_name": "amtk",
#     "description": "Actions, Menus and Toolbars Kit for GNOME",
#     "analytics_30d": 16,
#     "analytics_90d": 60,
#     "analytics_365d": 400
#   },
#   {
#     "pkg_name": "amtterm",
#     "description": "Serial-over-LAN (sol) client for Intel AMT",
#     "analytics_30d": 9,
#     "analytics_90d": 20,
#     "analytics_365d": 81
#   },
#   {
#     "pkg_name": "analog",
#     "description": "Logfile analyzer",
#     "analytics_30d": 10,
#     "analytics_90d": 27,
#     "analytics_365d": 134
#   },
#   {
#     "pkg_name": "angband",
#     "description": "Dungeon exploration game",
#     "analytics_30d": 44,
#     "analytics_90d": 158,
#     "analytics_365d": 677
#   },
#   {
#     "pkg_name": "angle-grinder",
#     "description": "Slice and dice log files on the command-line",
#     "analytics_30d": 34,
#     "analytics_90d": 222,
#     "analytics_365d": 692
#   },
#   {
#     "pkg_name": "angular-cli",
#     "description": "CLI tool for Angular",
#     "analytics_30d": 2976,
#     "analytics_90d": 9867,
#     "analytics_365d": 35518
#   },
#   {
#     "pkg_name": "anime-downloader",
#     "description": "Download your favourite anime",
#     "analytics_30d": 149,
#     "analytics_90d": 281,
#     "analytics_365d": 1105
#   },
#   {
#     "pkg_name": "anjuta",
#     "description": "GNOME Integrated Development Environment",
#     "analytics_30d": 28,
#     "analytics_90d": 83,
#     "analytics_365d": 604
#   },
#   {
#     "pkg_name": "annie",
#     "description": "Fast, simple and clean video downloader",
#     "analytics_30d": 536,
#     "analytics_90d": 2034,
#     "analytics_365d": 6791
#   },
#   {
#     "pkg_name": "ansible",
#     "description": "Automate deployment, configuration, and upgrading",
#     "analytics_30d": 21299,
#     "analytics_90d": 95592,
#     "analytics_365d": 361198
#   },
#   {
#     "pkg_name": "ansible-cmdb",
#     "description": "Generates static HTML overview page from Ansible facts",
#     "analytics_30d": 32,
#     "analytics_90d": 101,
#     "analytics_365d": 510
#   },
#   {
#     "pkg_name": "ansible-lint",
#     "description": "Checks ansible playbooks for practices and behaviour",
#     "analytics_30d": 976,
#     "analytics_90d": 2983,
#     "analytics_365d": 10316
#   },
#   {
#     "pkg_name": "ansible@2.8",
#     "description": "Automate deployment, configuration, and upgrading",
#     "analytics_30d": 290,
#     "analytics_90d": 961,
#     "analytics_365d": 1080
#   },
#   {
#     "pkg_name": "ansifilter",
#     "description": "Strip or convert ANSI codes into HTML, (La)Tex, RTF, or BBCode",
#     "analytics_30d": 117,
#     "analytics_90d": 562,
#     "analytics_365d": 1895
#   },
#   {
#     "pkg_name": "ansiweather",
#     "description": "Weather in your terminal, with ANSI colors and Unicode symbols",
#     "analytics_30d": 209,
#     "analytics_90d": 1157,
#     "analytics_365d": 3669
#   },
#   {
#     "pkg_name": "ant",
#     "description": "Java build tool",
#     "analytics_30d": 7153,
#     "analytics_90d": 26422,
#     "analytics_365d": 100980
#   },
#   {
#     "pkg_name": "ant-contrib",
#     "description": "Collection of tasks for Apache Ant",
#     "analytics_30d": 49,
#     "analytics_90d": 147,
#     "analytics_365d": 720
#   },
#   {
#     "pkg_name": "ant@1.9",
#     "description": "Java build tool",
#     "analytics_30d": 124,
#     "analytics_90d": 466,
#     "analytics_365d": 2039
#   },
#   {
#     "pkg_name": "antibody",
#     "description": "The fastest shell plugin manager",
#     "analytics_30d": 720,
#     "analytics_90d": 1277,
#     "analytics_365d": 2390
#   },
#   {
#     "pkg_name": "antigen",
#     "description": "Plugin manager for zsh, inspired by oh-my-zsh and vundle",
#     "analytics_30d": 748,
#     "analytics_90d": 2534,
#     "analytics_365d": 9412
#   },
#   {
#     "pkg_name": "antiword",
#     "description": "Utility to read Word (.doc) files",
#     "analytics_30d": 202,
#     "analytics_90d": 595,
#     "analytics_365d": 2813
#   },
#   {
#     "pkg_name": "antlr",
#     "description": "ANother Tool for Language Recognition",
#     "analytics_30d": 403,
#     "analytics_90d": 2053,
#     "analytics_365d": 6201
#   },
#   {
#     "pkg_name": "antlr@2",
#     "description": "ANother Tool for Language Recognition",
#     "analytics_30d": 13,
#     "analytics_90d": 82,
#     "analytics_365d": 148
#   },
#   {
#     "pkg_name": "antlr4-cpp-runtime",
#     "description": "ANother Tool for Language Recognition C++ Runtime Library",
#     "analytics_30d": 132,
#     "analytics_90d": 509,
#     "analytics_365d": 3042
#   },
#   {
#     "pkg_name": "anttweakbar",
#     "description": "C/C++ library for adding GUIs to OpenGL apps",
#     "analytics_30d": 23,
#     "analytics_90d": 70,
#     "analytics_365d": 274
#   },
#   {
#     "pkg_name": "anycable-go",
#     "description": "Anycable Go WebSocket Server",
#     "analytics_30d": 156,
#     "analytics_90d": 265,
#     "analytics_365d": 798
#   },
#   {
#     "pkg_name": "anyenv",
#     "description": "All in one for **env",
#     "analytics_30d": 1108,
#     "analytics_90d": 2797,
#     "analytics_365d": 9566
#   },
#   {
#     "pkg_name": "aoeui",
#     "description": "Lightweight text editor optimized for Dvorak and QWERTY keyboards",
#     "analytics_30d": 1,
#     "analytics_90d": 6,
#     "analytics_365d": 34
#   },
#   {
#     "pkg_name": "aom",
#     "description": "Codec library for encoding and decoding AV1 video streams",
#     "analytics_30d": 324,
#     "analytics_90d": 922,
#     "analytics_365d": 4647
#   },
#   {
#     "pkg_name": "apache-archiva",
#     "description": "The Build Artifact Repository Manager",
#     "analytics_30d": 14,
#     "analytics_90d": 56,
#     "analytics_365d": 141
#   },
#   {
#     "pkg_name": "apache-arrow",
#     "description": "Columnar in-memory analytics layer designed to accelerate big data",
#     "analytics_30d": 301,
#     "analytics_90d": 953,
#     "analytics_365d": 3737
#   },
#   {
#     "pkg_name": "apache-arrow-glib",
#     "description": "GLib bindings for Apache Arrow",
#     "analytics_30d": 55,
#     "analytics_90d": 409,
#     "analytics_365d": 1539
#   },
#   {
#     "pkg_name": "apache-brooklyn-cli",
#     "description": "Apache Brooklyn command-line interface",
#     "analytics_30d": 35,
#     "analytics_90d": 42,
#     "analytics_365d": 94
#   },
#   {
#     "pkg_name": "apache-ctakes",
#     "description": "NLP system for extraction of information from EMR clinical text",
#     "analytics_30d": 5,
#     "analytics_90d": 40,
#     "analytics_365d": 87
#   },
#   {
#     "pkg_name": "apache-drill",
#     "description": "Schema-free SQL Query Engine for Hadoop, NoSQL and Cloud Storage",
#     "analytics_30d": 93,
#     "analytics_90d": 219,
#     "analytics_365d": 816
#   },
#   {
#     "pkg_name": "apache-flink",
#     "description": "Scalable batch and stream data processing",
#     "analytics_30d": 940,
#     "analytics_90d": 3539,
#     "analytics_365d": 18376
#   },
#   {
#     "pkg_name": "apache-forrest",
#     "description": "Publishing framework providing multiple output formats",
#     "analytics_30d": 5,
#     "analytics_90d": 53,
#     "analytics_365d": 88
#   },
#   {
#     "pkg_name": "apache-geode",
#     "description": "In-memory Data Grid for fast transactional data processing",
#     "analytics_30d": 36,
#     "analytics_90d": 60,
#     "analytics_365d": 324
#   },
#   {
#     "pkg_name": "apache-opennlp",
#     "description": "Machine learning toolkit for processing natural language text",
#     "analytics_30d": 32,
#     "analytics_90d": 102,
#     "analytics_365d": 348
#   },
#   {
#     "pkg_name": "apache-spark",
#     "description": "Engine for large-scale data processing",
#     "analytics_30d": 5254,
#     "analytics_90d": 18064,
#     "analytics_365d": 63430
#   },
#   {
#     "pkg_name": "apachetop",
#     "description": "Top-like display of Apache log",
#     "analytics_30d": 20,
#     "analytics_90d": 81,
#     "analytics_365d": 284
#   },
#   {
#     "pkg_name": "apcupsd",
#     "description": "Daemon for controlling APC UPSes",
#     "analytics_30d": 50,
#     "analytics_90d": 115,
#     "analytics_365d": 422
#   },
#   {
#     "pkg_name": "ape",
#     "description": "Ajax Push Engine",
#     "analytics_30d": 7,
#     "analytics_90d": 20,
#     "analytics_365d": 75
#   },
#   {
#     "pkg_name": "apgdiff",
#     "description": "Another PostgreSQL diff tool",
#     "analytics_30d": 23,
#     "analytics_90d": 63,
#     "analytics_365d": 224
#   },
#   {
#     "pkg_name": "apib",
#     "description": "HTTP performance-testing tool",
#     "analytics_30d": 59,
#     "analytics_90d": 140,
#     "analytics_365d": 542
#   },
#   {
#     "pkg_name": "apibuilder-cli",
#     "description": "Command-line interface to generate clients for api builder",
#     "analytics_30d": 69,
#     "analytics_90d": 172,
#     "analytics_365d": 301
#   },
#   {
#     "pkg_name": "apktool",
#     "description": "Tool for reverse engineering 3rd party, closed, binary Android apps",
#     "analytics_30d": 2041,
#     "analytics_90d": 5534,
#     "analytics_365d": 27006
#   },
#   {
#     "pkg_name": "apm-bash-completion",
#     "description": "Completion for Atom Package Manager",
#     "analytics_30d": 34,
#     "analytics_90d": 104,
#     "analytics_365d": 419
#   },
#   {
#     "pkg_name": "apng2gif",
#     "description": "Convert APNG animations into animated GIF format",
#     "analytics_30d": 4,
#     "analytics_90d": 25,
#     "analytics_365d": 82
#   },
#   {
#     "pkg_name": "apngasm",
#     "description": "Next generation of apngasm, the APNG assembler",
#     "analytics_30d": 30,
#     "analytics_90d": 199,
#     "analytics_365d": 465
#   },
#   {
#     "pkg_name": "apollo",
#     "description": "Multi-protocol messaging broker based on ActiveMQ",
#     "analytics_30d": 92,
#     "analytics_90d": 305,
#     "analytics_365d": 973
#   },
#   {
#     "pkg_name": "apollo-cli",
#     "description": "Command-line tool for Apollo GraphQL",
#     "analytics_30d": 64,
#     "analytics_90d": 198,
#     "analytics_365d": 199
#   },
#   {
#     "pkg_name": "app-engine-java",
#     "description": "Google App Engine for Java",
#     "analytics_30d": 11,
#     "analytics_90d": 57,
#     "analytics_365d": 428
#   },
#   {
#     "pkg_name": "app-engine-python",
#     "description": "Google App Engine",
#     "analytics_30d": 31,
#     "analytics_90d": 71,
#     "analytics_365d": 468
#   },
#   {
#     "pkg_name": "apparix",
#     "description": "File system navigation via bookmarking directories",
#     "analytics_30d": 8,
#     "analytics_90d": 22,
#     "analytics_365d": 126
#   },
#   {
#     "pkg_name": "appium",
#     "description": "Automation for Apps",
#     "analytics_30d": 402,
#     "analytics_90d": 1343,
#     "analytics_365d": 2860
#   },
#   {
#     "pkg_name": "appledoc",
#     "description": "Objective-C API documentation generator",
#     "analytics_30d": 104,
#     "analytics_90d": 312,
#     "analytics_365d": 1959
#   },
#   {
#     "pkg_name": "appscale-tools",
#     "description": "Command-line tools for working with AppScale",
#     "analytics_30d": 2,
#     "analytics_90d": 11,
#     "analytics_365d": 303
#   },
#   {
#     "pkg_name": "appstream-glib",
#     "description": "Helper library for reading and writing AppStream metadata",
#     "analytics_30d": 9,
#     "analytics_90d": 83,
#     "analytics_365d": 411
#   },
#   {
#     "pkg_name": "apr",
#     "description": "Apache Portable Runtime library",
#     "analytics_30d": 585,
#     "analytics_90d": 1674,
#     "analytics_365d": 9658
#   },
#   {
#     "pkg_name": "apr-util",
#     "description": "Companion library to apr, the Apache Portable Runtime library",
#     "analytics_30d": 777,
#     "analytics_90d": 2109,
#     "analytics_365d": 12401
#   },
#   {
#     "pkg_name": "apt-dater",
#     "description": "Manage package updates on remote hosts using SSH",
#     "analytics_30d": 35,
#     "analytics_90d": 131,
#     "analytics_365d": 615
#   },
#   {
#     "pkg_name": "aptly",
#     "description": "Swiss army knife for Debian repository management",
#     "analytics_30d": 60,
#     "analytics_90d": 202,
#     "analytics_365d": 805
#   },
#   {
#     "pkg_name": "aqbanking",
#     "description": "Generic online banking interface",
#     "analytics_30d": 13,
#     "analytics_90d": 70,
#     "analytics_365d": 466
#   },
#   {
#     "pkg_name": "arabica",
#     "description": "XML toolkit written in C++",
#     "analytics_30d": 2,
#     "analytics_90d": 9,
#     "analytics_365d": 76
#   },
#   {
#     "pkg_name": "arangodb",
#     "description": "The Multi-Model NoSQL Database",
#     "analytics_30d": 283,
#     "analytics_90d": 982,
#     "analytics_365d": 4473
#   },
#   {
#     "pkg_name": "aravis",
#     "description": "Vision library for genicam based cameras",
#     "analytics_30d": 6,
#     "analytics_90d": 46,
#     "analytics_365d": 531
#   },
#   {
#     "pkg_name": "arcade-learning-environment",
#     "description": "Platform for AI research",
#     "analytics_30d": 8,
#     "analytics_90d": 46,
#     "analytics_365d": 247
#   },
#   {
#     "pkg_name": "archey",
#     "description": "Graphical system information display for macOS",
#     "analytics_30d": 667,
#     "analytics_90d": 1853,
#     "analytics_365d": 7563
#   },
#   {
#     "pkg_name": "archi-steam-farm",
#     "description": "ASF is a C# application that allows you to farm steam cards",
#     "analytics_30d": 11,
#     "analytics_90d": 21,
#     "analytics_365d": 88
#   },
#   {
#     "pkg_name": "archivemount",
#     "description": "File system for accessing archives using libarchive",
#     "analytics_30d": 11,
#     "analytics_90d": 32,
#     "analytics_365d": 140
#   },
#   {
#     "pkg_name": "archiver",
#     "description": "Cross-platform, multi-format archive utility",
#     "analytics_30d": 18,
#     "analytics_90d": 32,
#     "analytics_365d": 34
#   },
#   {
#     "pkg_name": "arduino-cli",
#     "description": "Arduino command-line interface",
#     "analytics_30d": 344,
#     "analytics_90d": 1356,
#     "analytics_365d": 2752
#   },
#   {
#     "pkg_name": "argon2",
#     "description": "Password hashing library and CLI utility",
#     "analytics_30d": 175,
#     "analytics_90d": 517,
#     "analytics_365d": 3300
#   },
#   {
#     "pkg_name": "argp-standalone",
#     "description": "Standalone version of arguments parsing functions from GLIBC",
#     "analytics_30d": 92,
#     "analytics_90d": 278,
#     "analytics_365d": 1143
#   },
#   {
#     "pkg_name": "argtable",
#     "description": "ANSI C library for parsing GNU-style command-line options",
#     "analytics_30d": 53,
#     "analytics_90d": 129,
#     "analytics_365d": 467
#   },
#   {
#     "pkg_name": "argus",
#     "description": "Audit Record Generation and Utilization System server",
#     "analytics_30d": 18,
#     "analytics_90d": 33,
#     "analytics_365d": 131
#   },
#   {
#     "pkg_name": "argus-clients",
#     "description": "Audit Record Generation and Utilization System clients",
#     "analytics_30d": 8,
#     "analytics_90d": 28,
#     "analytics_365d": 310
#   },
#   {
#     "pkg_name": "argyll-cms",
#     "description": "ICC compatible color management system",
#     "analytics_30d": 43,
#     "analytics_90d": 185,
#     "analytics_365d": 566
#   },
#   {
#     "pkg_name": "aria2",
#     "description": "Download with resuming and segmented downloading",
#     "analytics_30d": 3173,
#     "analytics_90d": 9449,
#     "analytics_365d": 43541
#   },
#   {
#     "pkg_name": "arm-linux-gnueabihf-binutils",
#     "description": "FSF/GNU binutils for cross-compiling to arm-linux",
#     "analytics_30d": 246,
#     "analytics_90d": 728,
#     "analytics_365d": 2236
#   },
#   {
#     "pkg_name": "armadillo",
#     "description": "C++ linear algebra library",
#     "analytics_30d": 766,
#     "analytics_90d": 2340,
#     "analytics_365d": 8112
#   },
#   {
#     "pkg_name": "armor",
#     "description": "Uncomplicated, modern HTTP server",
#     "analytics_30d": 5,
#     "analytics_90d": 23,
#     "analytics_365d": 157
#   },
#   {
#     "pkg_name": "arp-scan",
#     "description": "ARP scanning and fingerprinting tool",
#     "analytics_30d": 1091,
#     "analytics_90d": 3254,
#     "analytics_365d": 14413
#   },
#   {
#     "pkg_name": "arp-sk",
#     "description": "ARP traffic generation tool",
#     "analytics_30d": 16,
#     "analytics_90d": 44,
#     "analytics_365d": 131
#   },
#   {
#     "pkg_name": "arpack",
#     "description": "Routines to solve large scale eigenvalue problems",
#     "analytics_30d": 377,
#     "analytics_90d": 1055,
#     "analytics_365d": 4754
#   },
#   {
#     "pkg_name": "arping",
#     "description": "Utility to check whether MAC addresses are already taken on a LAN",
#     "analytics_30d": 1135,
#     "analytics_90d": 2723,
#     "analytics_365d": 7913
#   },
#   {
#     "pkg_name": "arpoison",
#     "description": "UNIX arp cache update utility",
#     "analytics_30d": 3042,
#     "analytics_90d": 11036,
#     "analytics_365d": 48993
#   },
#   {
#     "pkg_name": "arss",
#     "description": "Analyze a sound file into a spectrogram",
#     "analytics_30d": 3,
#     "analytics_90d": 23,
#     "analytics_365d": 191
#   },
#   {
#     "pkg_name": "artifactory",
#     "description": "Manages binaries",
#     "analytics_30d": 153,
#     "analytics_90d": 437,
#     "analytics_365d": 1225
#   },
#   {
#     "pkg_name": "arx-libertatis",
#     "description": "Cross-platform, open source port of Arx Fatalis",
#     "analytics_30d": 7,
#     "analytics_90d": 16,
#     "analytics_365d": 152
#   },
#   {
#     "pkg_name": "ascii",
#     "description": "List ASCII idiomatic names and octal/decimal code-point forms",
#     "analytics_30d": 82,
#     "analytics_90d": 252,
#     "analytics_365d": 1024
#   },
#   {
#     "pkg_name": "asciidoc",
#     "description": "Formatter/translator for text files to numerous formats. Includes a2x",
#     "analytics_30d": 328,
#     "analytics_90d": 1136,
#     "analytics_365d": 4308
#   },
#   {
#     "pkg_name": "asciidoctor",
#     "description": "Text processor and publishing toolchain for AsciiDoc",
#     "analytics_30d": 861,
#     "analytics_90d": 2232,
#     "analytics_365d": 10698
#   },
#   {
#     "pkg_name": "asciidoctorj",
#     "description": "Java wrapper and bindings for Asciidoctor",
#     "analytics_30d": 22,
#     "analytics_90d": 136,
#     "analytics_365d": 377
#   },
#   {
#     "pkg_name": "asciinema",
#     "description": "Record and share terminal sessions",
#     "analytics_30d": 3179,
#     "analytics_90d": 9750,
#     "analytics_365d": 24213
#   },
#   {
#     "pkg_name": "asciiquarium",
#     "description": "Aquarium animation in ASCII art",
#     "analytics_30d": 151,
#     "analytics_90d": 532,
#     "analytics_365d": 2297
#   },
#   {
#     "pkg_name": "asciitex",
#     "description": "Generate ASCII-art representations of mathematical equations",
#     "analytics_30d": 9,
#     "analytics_90d": 22,
#     "analytics_365d": 87
#   },
#   {
#     "pkg_name": "asdf",
#     "description": "Extendable version manager with support for Ruby, Node.js, Erlang & more",
#     "analytics_30d": 5581,
#     "analytics_90d": 13159,
#     "analytics_365d": 39900
#   },
#   {
#     "pkg_name": "asio",
#     "description": "Cross-platform C++ Library for asynchronous programming",
#     "analytics_30d": 356,
#     "analytics_90d": 905,
#     "analytics_365d": 3587
#   },
#   {
#     "pkg_name": "ask-cli",
#     "description": "CLI tool for Alexa Skill Kit",
#     "analytics_30d": 100,
#     "analytics_90d": 321,
#     "analytics_365d": 1477
#   },
#   {
#     "pkg_name": "asn1c",
#     "description": "Compile ASN.1 specifications into C source code",
#     "analytics_30d": 17,
#     "analytics_90d": 60,
#     "analytics_365d": 244
#   },
#   {
#     "pkg_name": "aspcud",
#     "description": "Package dependency solver",
#     "analytics_30d": 29,
#     "analytics_90d": 114,
#     "analytics_365d": 589
#   },
#   {
#     "pkg_name": "aspectj",
#     "description": "Aspect-oriented programming for Java",
#     "analytics_30d": 13,
#     "analytics_90d": 97,
#     "analytics_365d": 455
#   },
#   {
#     "pkg_name": "aspell",
#     "description": "Spell checker with better logic than ispell",
#     "analytics_30d": 1675,
#     "analytics_90d": 5194,
#     "analytics_365d": 28484
#   },
#   {
#     "pkg_name": "assh",
#     "description": "Advanced SSH config - Regex, aliases, gateways, includes and dynamic hosts",
#     "analytics_30d": 340,
#     "analytics_90d": 407,
#     "analytics_365d": 909
#   },
#   {
#     "pkg_name": "assimp",
#     "description": "Portable library for importing many well-known 3D model formats",
#     "analytics_30d": 568,
#     "analytics_90d": 1839,
#     "analytics_365d": 6200
#   },
#   {
#     "pkg_name": "astrometry-net",
#     "description": "Automatic identification of astronomical images",
#     "analytics_30d": 112,
#     "analytics_90d": 304,
#     "analytics_365d": 1102
#   },
#   {
#     "pkg_name": "astyle",
#     "description": "Source code beautifier for C, C++, C#, and Java",
#     "analytics_30d": 241,
#     "analytics_90d": 575,
#     "analytics_365d": 2607
#   },
#   {
#     "pkg_name": "asymptote",
#     "description": "Powerful descriptive vector graphics language",
#     "analytics_30d": 67,
#     "analytics_90d": 174,
#     "analytics_365d": 182
#   },
#   {
#     "pkg_name": "asyncplusplus",
#     "description": "Concurrency framework for C++11",
#     "analytics_30d": 2,
#     "analytics_90d": 9,
#     "analytics_365d": 55
#   },
#   {
#     "pkg_name": "atari800",
#     "description": "Atari 8-bit machine emulator",
#     "analytics_30d": 22,
#     "analytics_90d": 131,
#     "analytics_365d": 396
#   },
#   {
#     "pkg_name": "atasm",
#     "description": "Atari MAC/65 compatible assembler for Unix",
#     "analytics_30d": 5,
#     "analytics_90d": 14,
#     "analytics_365d": 29
#   },
#   {
#     "pkg_name": "atdtool",
#     "description": "Command-line interface for After the Deadline language checker",
#     "analytics_30d": 13,
#     "analytics_90d": 34,
#     "analytics_365d": 136
#   },
#   {
#     "pkg_name": "aterm",
#     "description": "Annotated Term for tree-like ADT exchange",
#     "analytics_30d": 7,
#     "analytics_90d": 15,
#     "analytics_365d": 56
#   },
#   {
#     "pkg_name": "atf",
#     "description": "ATF: Automated Testing Framework",
#     "analytics_30d": 1,
#     "analytics_90d": 3,
#     "analytics_365d": 22
#   },
#   {
#     "pkg_name": "atk",
#     "description": "GNOME accessibility toolkit",
#     "analytics_30d": 1742,
#     "analytics_90d": 2528,
#     "analytics_365d": 10753
#   },
#   {
#     "pkg_name": "atkmm",
#     "description": "Official C++ interface for the ATK accessibility toolkit library",
#     "analytics_30d": 72,
#     "analytics_90d": 198,
#     "analytics_365d": 1939
#   },
#   {
#     "pkg_name": "atlantis",
#     "description": "Terraform Pull Request Automation tool",
#     "analytics_30d": 25,
#     "analytics_90d": 140,
#     "analytics_365d": 590
#   },
#   {
#     "pkg_name": "atlassian-cli",
#     "description": "Command-line interface clients for Atlassian products",
#     "analytics_30d": 129,
#     "analytics_90d": 489,
#     "analytics_365d": 1156
#   },
#   {
#     "pkg_name": "atomicparsley",
#     "description": "MPEG-4 command-line tool",
#     "analytics_30d": 242,
#     "analytics_90d": 651,
#     "analytics_365d": 2328
#   },
#   {
#     "pkg_name": "atomist-cli",
#     "description": "The Atomist CLI",
#     "analytics_30d": 21,
#     "analytics_90d": 52,
#     "analytics_365d": 481
#   },
#   {
#     "pkg_name": "atool",
#     "description": "Archival front-end",
#     "analytics_30d": 118,
#     "analytics_90d": 329,
#     "analytics_365d": 1427
#   },
#   {
#     "pkg_name": "ats2-postiats",
#     "description": "Programming language with formal specification features",
#     "analytics_30d": 10,
#     "analytics_90d": 58,
#     "analytics_365d": 160
#   },
#   {
#     "pkg_name": "aubio",
#     "description": "Extract annotations from audio signals",
#     "analytics_30d": 265,
#     "analytics_90d": 420,
#     "analytics_365d": 1080
#   },
#   {
#     "pkg_name": "audacious",
#     "description": "Free and advanced audio player based on GTK+",
#     "analytics_30d": 146,
#     "analytics_90d": 298,
#     "analytics_365d": 1260
#   },
#   {
#     "pkg_name": "audiofile",
#     "description": "Reads and writes many common audio file formats",
#     "analytics_30d": 16,
#     "analytics_90d": 37,
#     "analytics_365d": 119
#   },
#   {
#     "pkg_name": "auditbeat",
#     "description": "Lightweight Shipper for Audit Data",
#     "analytics_30d": 30,
#     "analytics_90d": 100,
#     "analytics_365d": 413
#   },
#   {
#     "pkg_name": "augeas",
#     "description": "Configuration editing tool and API",
#     "analytics_30d": 229,
#     "analytics_90d": 775,
#     "analytics_365d": 5854
#   },
#   {
#     "pkg_name": "augustus",
#     "description": "Predict genes in eukaryotic genomic sequences",
#     "analytics_30d": 12,
#     "analytics_90d": 43,
#     "analytics_365d": 214
#   },
#   {
#     "pkg_name": "aurora",
#     "description": "Beanstalkd queue server console",
#     "analytics_30d": 17,
#     "analytics_90d": 38,
#     "analytics_365d": 405
#   },
#   {
#     "pkg_name": "aurora-cli",
#     "description": "Apache Aurora Scheduler Client",
#     "analytics_30d": 44,
#     "analytics_90d": 95,
#     "analytics_365d": 331
#   },
#   {
#     "pkg_name": "autobench",
#     "description": "Automatic webserver benchmark tool",
#     "analytics_30d": 8,
#     "analytics_90d": 28,
#     "analytics_365d": 131
#   },
#   {
#     "pkg_name": "autocode",
#     "description": "Code automation for every language, library and framework",
#     "analytics_30d": 21,
#     "analytics_90d": 66,
#     "analytics_365d": 300
#   },
#   {
#     "pkg_name": "autoconf",
#     "description": "Automatic configure script builder",
#     "analytics_30d": 21277,
#     "analytics_90d": 60964,
#     "analytics_365d": 246960
#   },
#   {
#     "pkg_name": "autoconf-archive",
#     "description": "Collection of over 500 reusable autoconf macros",
#     "analytics_30d": 292,
#     "analytics_90d": 854,
#     "analytics_365d": 4080
#   },
#   {
#     "pkg_name": "autoconf@2.13",
#     "description": "Automatic configure script builder",
#     "analytics_30d": 176,
#     "analytics_90d": 596,
#     "analytics_365d": 2404
#   },
#   {
#     "pkg_name": "autoenv",
#     "description": "Per-project, per-directory shell environments",
#     "analytics_30d": 370,
#     "analytics_90d": 1064,
#     "analytics_365d": 4778
#   },
#   {
#     "pkg_name": "autogen",
#     "description": "Automated text file generator",
#     "analytics_30d": 306,
#     "analytics_90d": 848,
#     "analytics_365d": 3627
#   },
#   {
#     "pkg_name": "autojump",
#     "description": "Shell extension to jump to frequently used directories",
#     "analytics_30d": 4248,
#     "analytics_90d": 11901,
#     "analytics_365d": 60538
#   },
#   {
#     "pkg_name": "automake",
#     "description": "Tool for generating GNU Standards-compliant Makefiles",
#     "analytics_30d": 69215,
#     "analytics_90d": 129780,
#     "analytics_365d": 409223
#   },
#   {
#     "pkg_name": "automysqlbackup",
#     "description": "Automate MySQL backups",
#     "analytics_30d": 21,
#     "analytics_90d": 51,
#     "analytics_365d": 192
#   },
#   {
#     "pkg_name": "autopano-sift-c",
#     "description": "Find control points in overlapping image pairs",
#     "analytics_30d": 4,
#     "analytics_90d": 13,
#     "analytics_365d": 106
#   },
#   {
#     "pkg_name": "autopep8",
#     "description": "Automatically formats Python code to conform to the PEP 8 style guide",
#     "analytics_30d": 660,
#     "analytics_90d": 1839,
#     "analytics_365d": 4564
#   },
#   {
#     "pkg_name": "autopsy",
#     "description": "Graphical interface to Sleuth Kit investigation tools",
#     "analytics_30d": 273,
#     "analytics_90d": 551,
#     "analytics_365d": 1721
#   },
#   {
#     "pkg_name": "autorest",
#     "description": "Swagger (OpenAPI) Specification code generator",
#     "analytics_30d": 20,
#     "analytics_90d": 84,
#     "analytics_365d": 441
#   },
#   {
#     "pkg_name": "autossh",
#     "description": "Automatically restart SSH sessions and tunnels",
#     "analytics_30d": 991,
#     "analytics_90d": 2839,
#     "analytics_365d": 12177
#   },
#   {
#     "pkg_name": "avanor",
#     "description": "Quick-growing roguelike game with easy ADOM-like UI",
#     "analytics_30d": 5,
#     "analytics_90d": 14,
#     "analytics_365d": 63
#   },
#   {
#     "pkg_name": "avce00",
#     "description": "Make Arc/Info (binary) Vector Coverages appear as E00",
#     "analytics_30d": 1,
#     "analytics_90d": 4,
#     "analytics_365d": 18
#   },
#   {
#     "pkg_name": "avfs",
#     "description": "Virtual file system that facilitates looking inside archives",
#     "analytics_30d": 8,
#     "analytics_90d": 17,
#     "analytics_365d": 229
#   },
#   {
#     "pkg_name": "avian",
#     "description": "Lightweight VM and class library for a subset of Java features",
#     "analytics_30d": 2,
#     "analytics_90d": 3,
#     "analytics_365d": 22
#   },
#   {
#     "pkg_name": "aview",
#     "description": "ASCII-art image browser and animation viewer",
#     "analytics_30d": 33,
#     "analytics_90d": 116,
#     "analytics_365d": 499
#   },
#   {
#     "pkg_name": "avimetaedit",
#     "description": "Tool for embedding, validating, and exporting of AVI files metadata",
#     "analytics_30d": 3,
#     "analytics_90d": 5,
#     "analytics_365d": 36
#   },
#   {
#     "pkg_name": "avra",
#     "description": "Assember for the Atmel AVR microcontroller family",
#     "analytics_30d": 25,
#     "analytics_90d": 61,
#     "analytics_365d": 349
#   },
#   {
#     "pkg_name": "avrdude",
#     "description": "Atmel AVR MCU programmer",
#     "analytics_30d": 1357,
#     "analytics_90d": 3713,
#     "analytics_365d": 14779
#   },
#   {
#     "pkg_name": "avro-c",
#     "description": "Data serialization system",
#     "analytics_30d": 23,
#     "analytics_90d": 143,
#     "analytics_365d": 487
#   },
#   {
#     "pkg_name": "avro-cpp",
#     "description": "Data serialization system",
#     "analytics_30d": 16,
#     "analytics_90d": 79,
#     "analytics_365d": 374
#   },
#   {
#     "pkg_name": "avro-tools",
#     "description": "Avro command-line tools and utilities",
#     "analytics_30d": 382,
#     "analytics_90d": 1462,
#     "analytics_365d": 4940
#   },
#   {
#     "pkg_name": "awf",
#     "description": "'A Widget Factory' is a theme preview application for gtk2 and gtk3",
#     "analytics_30d": 4,
#     "analytics_90d": 24,
#     "analytics_365d": 269
#   },
#   {
#     "pkg_name": "awk",
#     "description": "Text processing scripting language",
#     "analytics_30d": 486,
#     "analytics_90d": 1429,
#     "analytics_365d": 6620
#   },
#   {
#     "pkg_name": "aws-apigateway-importer",
#     "description": "AWS API Gateway Importer",
#     "analytics_30d": 9,
#     "analytics_90d": 32,
#     "analytics_365d": 147
#   },
#   {
#     "pkg_name": "aws-cdk",
#     "description": "AWS Cloud Development Kit - framework for defining AWS infra as code",
#     "analytics_30d": 1403,
#     "analytics_90d": 3250,
#     "analytics_365d": 5493
#   },
#   {
#     "pkg_name": "aws-cfn-tools",
#     "description": "Client for Amazon CloudFormation web service",
#     "analytics_30d": 81,
#     "analytics_90d": 339,
#     "analytics_365d": 685
#   },
#   {
#     "pkg_name": "aws-elasticbeanstalk",
#     "description": "Client for Amazon Elastic Beanstalk web service",
#     "analytics_30d": 3851,
#     "analytics_90d": 12503,
#     "analytics_365d": 36898
#   },
#   {
#     "pkg_name": "aws-es-proxy",
#     "description": "Small proxy between HTTP client and AWS Elasticsearch",
#     "analytics_30d": 133,
#     "analytics_90d": 310,
#     "analytics_365d": 978
#   },
#   {
#     "pkg_name": "aws-google-auth",
#     "description": "Acquire AWS credentials using Google Apps",
#     "analytics_30d": 342,
#     "analytics_90d": 1191,
#     "analytics_365d": 2104
#   },
#   {
#     "pkg_name": "aws-iam-authenticator",
#     "description": "Use AWS IAM credentials to authenticate to Kubernetes",
#     "analytics_30d": 4901,
#     "analytics_90d": 17642,
#     "analytics_365d": 53930
#   },
#   {
#     "pkg_name": "aws-keychain",
#     "description": "Uses macOS keychain for storage of AWS credentials",
#     "analytics_30d": 25,
#     "analytics_90d": 63,
#     "analytics_365d": 351
#   },
#   {
#     "pkg_name": "aws-okta",
#     "description": "Authenticate with AWS using your Okta credentials",
#     "analytics_30d": 1866,
#     "analytics_90d": 5625,
#     "analytics_365d": 19339
#   },
#   {
#     "pkg_name": "aws-sdk-cpp",
#     "description": "AWS SDK for C++",
#     "analytics_30d": 138,
#     "analytics_90d": 604,
#     "analytics_365d": 2498
#   },
#   {
#     "pkg_name": "aws-shell",
#     "description": "Integrated shell for working with the AWS CLI",
#     "analytics_30d": 1181,
#     "analytics_90d": 3745,
#     "analytics_365d": 8749
#   },
#   {
#     "pkg_name": "awscli",
#     "description": "Official Amazon AWS command-line interface",
#     "analytics_30d": 95118,
#     "analytics_90d": 248546,
#     "analytics_365d": 817120
#   },
#   {
#     "pkg_name": "awscli@1",
#     "description": "Official Amazon AWS command-line interface",
#     "analytics_30d": 1522,
#     "analytics_90d": 3868,
#     "analytics_365d": 3868
#   },
#   {
#     "pkg_name": "awscurl",
#     "description": "Curl like simplicity to access AWS resources",
#     "analytics_30d": 131,
#     "analytics_90d": 389,
#     "analytics_365d": 515
#   },
#   {
#     "pkg_name": "awslogs",
#     "description": "Simple command-line tool to read AWS CloudWatch logs",
#     "analytics_30d": 709,
#     "analytics_90d": 1990,
#     "analytics_365d": 5242
#   },
#   {
#     "pkg_name": "awsume",
#     "description": "Utility for easily assuming AWS IAM roles from the command-line",
#     "analytics_30d": 252,
#     "analytics_90d": 703,
#     "analytics_365d": 1029
#   },
#   {
#     "pkg_name": "axel",
#     "description": "Light UNIX download accelerator",
#     "analytics_30d": 2457,
#     "analytics_90d": 6638,
#     "analytics_365d": 24428
#   },
#   {
#     "pkg_name": "azcopy",
#     "description": "Azure Storage data transfer utility",
#     "analytics_30d": 239,
#     "analytics_90d": 284,
#     "analytics_365d": 305
#   },
#   {
#     "pkg_name": "azure-cli",
#     "description": "Microsoft Azure CLI 2.0",
#     "analytics_30d": 20167,
#     "analytics_90d": 61882,
#     "analytics_365d": 218279
#   },
#   {
#     "pkg_name": "azure-storage-cpp",
#     "description": "Microsoft Azure Storage Client Library for C++",
#     "analytics_30d": 23,
#     "analytics_90d": 80,
#     "analytics_365d": 289
#   },
#   {
#     "pkg_name": "b2-tools",
#     "description": "B2 Cloud Storage Command-Line Tools",
#     "analytics_30d": 130,
#     "analytics_90d": 204,
#     "analytics_365d": 911
#   },
#   {
#     "pkg_name": "b2sum",
#     "description": "BLAKE2 b2sum reference binary",
#     "analytics_30d": 5,
#     "analytics_90d": 29,
#     "analytics_365d": 158
#   },
#   {
#     "pkg_name": "b3sum",
#     "description": "The BLAKE3 cryptographic hash function",
#     "analytics_30d": 56,
#     "analytics_90d": 151,
#     "analytics_365d": 166
#   },
#   {
#     "pkg_name": "b43-fwcutter",
#     "description": "Extract firmware from Braodcom 43xx driver files",
#     "analytics_30d": 5,
#     "analytics_90d": 12,
#     "analytics_365d": 49
#   },
#   {
#     "pkg_name": "babel",
#     "description": "Compiler for writing next generation JavaScript",
#     "analytics_30d": 505,
#     "analytics_90d": 1663,
#     "analytics_365d": 6983
#   },
#   {
#     "pkg_name": "babeld",
#     "description": "Loop-avoiding distance-vector routing protocol",
#     "analytics_30d": 3,
#     "analytics_90d": 6,
#     "analytics_365d": 62
#   },
#   {
#     "pkg_name": "babl",
#     "description": "Dynamic, any-to-any, pixel format translation library",
#     "analytics_30d": 61,
#     "analytics_90d": 191,
#     "analytics_365d": 764
#   },
#   {
#     "pkg_name": "backupninja",
#     "description": "Backup automation tool",
#     "analytics_30d": 4,
#     "analytics_90d": 16,
#     "analytics_365d": 88
#   },
#   {
#     "pkg_name": "bacula-fd",
#     "description": "Network backup solution",
#     "analytics_30d": 28,
#     "analytics_90d": 79,
#     "analytics_365d": 348
#   },
#   {
#     "pkg_name": "badtouch",
#     "description": "Scriptable network authentication cracker",
#     "analytics_30d": 10,
#     "analytics_90d": 26,
# ...
#     "description": "C++ YAML parser and emitter for YAML 1.2 spec",
#     "analytics_30d": 812,
#     "analytics_90d": 2429,
#     "analytics_365d": 12154
#   },
#   {
#     "pkg_name": "yamllint",
#     "description": "Linter for YAML files",
#     "analytics_30d": 4845,
#     "analytics_90d": 9588,
#     "analytics_365d": 28272
#   },
#   {
#     "pkg_name": "yank",
#     "description": "Copy terminal output to clipboard",
#     "analytics_30d": 42,
#     "analytics_90d": 140,
#     "analytics_365d": 994
#   },
#   {
#     "pkg_name": "yapf",
#     "description": "Formatter for python code",
#     "analytics_30d": 178,
#     "analytics_90d": 503,
#     "analytics_365d": 1464
#   },
#   {
#     "pkg_name": "yara",
#     "description": "Malware identification and classification tool",
#     "analytics_30d": 321,
#     "analytics_90d": 914,
#     "analytics_365d": 4756
#   },
#   {
#     "pkg_name": "yarn",
#     "description": "JavaScript package manager",
#     "analytics_30d": 135240,
#     "analytics_90d": 435317,
#     "analytics_365d": 1610234
#   },
#   {
#     "pkg_name": "yarn-completion",
#     "description": "Bash completion for Yarn",
#     "analytics_30d": 125,
#     "analytics_90d": 421,
#     "analytics_365d": 1644
#   },
#   {
#     "pkg_name": "yash",
#     "description": "Yet another shell: a POSIX-compliant command-line shell",
#     "analytics_30d": 18,
#     "analytics_90d": 34,
#     "analytics_365d": 173
#   },
#   {
#     "pkg_name": "yasm",
#     "description": "Modular BSD reimplementation of NASM",
#     "analytics_30d": 2297,
#     "analytics_90d": 5895,
#     "analytics_365d": 23195
#   },
#   {
#     "pkg_name": "yaws",
#     "description": "Webserver for dynamic content (written in Erlang)",
#     "analytics_30d": 9,
#     "analytics_90d": 33,
#     "analytics_365d": 186
#   },
#   {
#     "pkg_name": "yaz",
#     "description": "Toolkit for Z39.50/SRW/SRU clients/servers",
#     "analytics_30d": 93,
#     "analytics_90d": 248,
#     "analytics_365d": 718
#   },
#   {
#     "pkg_name": "yaze-ag",
#     "description": "Yet Another Z80 Emulator (by AG)",
#     "analytics_30d": 1,
#     "analytics_90d": 8,
#     "analytics_365d": 25
#   },
#   {
#     "pkg_name": "yazpp",
#     "description": "C++ API for the Yaz toolkit",
#     "analytics_30d": 1,
#     "analytics_90d": 6,
#     "analytics_365d": 11
#   },
#   {
#     "pkg_name": "yconalyzer",
#     "description": "TCP traffic analyzer",
#     "analytics_30d": 0,
#     "analytics_90d": 4,
#     "analytics_365d": 26
#   },
#   {
#     "pkg_name": "ydcv",
#     "description": "YouDao Console Version",
#     "analytics_30d": 10,
#     "analytics_90d": 34,
#     "analytics_365d": 209
#   },
#   {
#     "pkg_name": "ydiff",
#     "description": "View colored diff with side by side and auto pager support",
#     "analytics_30d": 81,
#     "analytics_90d": 233,
#     "analytics_365d": 1033
#   },
#   {
#     "pkg_name": "yelp-tools",
#     "description": "Tools that help create and edit Mallard or DocBook documentation",
#     "analytics_30d": 19,
#     "analytics_90d": 47,
#     "analytics_365d": 414
#   },
#   {
#     "pkg_name": "yeti",
#     "description": "ML-style functional programming language that runs on the JVM",
#     "analytics_30d": 0,
#     "analytics_90d": 2,
#     "analytics_365d": 20
#   },
#   {
#     "pkg_name": "yetris",
#     "description": "Customizable Tetris for the terminal",
#     "analytics_30d": 9,
#     "analytics_90d": 25,
#     "analytics_365d": 108
#   },
#   {
#     "pkg_name": "ykclient",
#     "description": "Library to validate YubiKey OTPs against YubiCloud",
#     "analytics_30d": 7,
#     "analytics_90d": 13,
#     "analytics_365d": 80
#   },
#   {
#     "pkg_name": "ykman",
#     "description": "Tool for managing your YubiKey configuration",
#     "analytics_30d": 1746,
#     "analytics_90d": 5861,
#     "analytics_365d": 19609
#   },
#   {
#     "pkg_name": "ykneomgr",
#     "description": "CLI and C library to interact with the CCID-part of the YubiKey NEO",
#     "analytics_30d": 26,
#     "analytics_90d": 67,
#     "analytics_365d": 413
#   },
#   {
#     "pkg_name": "ykpers",
#     "description": "YubiKey personalization library and tool",
#     "analytics_30d": 313,
#     "analytics_90d": 975,
#     "analytics_365d": 6448
#   },
#   {
#     "pkg_name": "yle-dl",
#     "description": "Download Yle videos from the command-line",
#     "analytics_30d": 89,
#     "analytics_90d": 315,
#     "analytics_365d": 1257
#   },
#   {
#     "pkg_name": "yosys",
#     "description": "Framework for Verilog RTL synthesis",
#     "analytics_30d": 45,
#     "analytics_90d": 140,
#     "analytics_365d": 669
#   },
#   {
#     "pkg_name": "you-get",
#     "description": "Dumb downloader that scrapes the web",
#     "analytics_30d": 2783,
#     "analytics_90d": 7909,
#     "analytics_365d": 25758
#   },
#   {
#     "pkg_name": "youtube-dl",
#     "description": "Download YouTube videos from the command-line",
#     "analytics_30d": 54647,
#     "analytics_90d": 182459,
#     "analytics_365d": 726204
#   },
#   {
#     "pkg_name": "yq",
#     "description": "Process YAML documents from the CLI",
#     "analytics_30d": 4273,
#     "analytics_90d": 21454,
#     "analytics_365d": 47795
#   },
#   {
#     "pkg_name": "yubico-piv-tool",
#     "description": "Command-line tool for the YubiKey PIV application",
#     "analytics_30d": 465,
#     "analytics_90d": 1603,
#     "analytics_365d": 4543
#   },
#   {
#     "pkg_name": "yuicompressor",
#     "description": "Yahoo! JavaScript and CSS compressor",
#     "analytics_30d": 85,
#     "analytics_90d": 225,
#     "analytics_365d": 1051
#   },
#   {
#     "pkg_name": "yydecode",
#     "description": "Decode yEnc archives",
#     "analytics_30d": 3,
#     "analytics_90d": 7,
#     "analytics_365d": 26
#   },
#   {
#     "pkg_name": "z",
#     "description": "Tracks most-used directories to make cd smarter",
#     "analytics_30d": 3368,
#     "analytics_90d": 8151,
#     "analytics_365d": 23508
#   },
#   {
#     "pkg_name": "z3",
#     "description": "High-performance theorem prover",
#     "analytics_30d": 286,
#     "analytics_90d": 918,
#     "analytics_365d": 5143
#   },
#   {
#     "pkg_name": "z80asm",
#     "description": "Assembler for the Zilog Z80 microprcessor and compatibles",
#     "analytics_30d": 6,
#     "analytics_90d": 31,
#     "analytics_365d": 118
#   },
#   {
#     "pkg_name": "z80dasm",
#     "description": "Disassembler for the Zilog Z80 microprocessor and compatibles",
#     "analytics_30d": 5,
#     "analytics_90d": 21,
#     "analytics_365d": 65
#   },
#   {
#     "pkg_name": "zabbix",
#     "description": "Availability and monitoring solution",
#     "analytics_30d": 957,
#     "analytics_90d": 2391,
#     "analytics_365d": 4984
#   },
#   {
#     "pkg_name": "zabbix-cli",
#     "description": "CLI tool for interacting with Zabbix monitoring system",
#     "analytics_30d": 18,
#     "analytics_90d": 81,
#     "analytics_365d": 214
#   },
#   {
#     "pkg_name": "zanata-client",
#     "description": "Zanata translation system command-line client",
#     "analytics_30d": 3,
#     "analytics_90d": 16,
#     "analytics_365d": 105
#   },
#   {
#     "pkg_name": "zbackup",
#     "description": "Globally-deduplicating backup tool (based on ideas in rsync)",
#     "analytics_30d": 6,
#     "analytics_90d": 16,
#     "analytics_365d": 233
#   },
#   {
#     "pkg_name": "zbar",
#     "description": "Suite of barcodes-reading tools",
#     "analytics_30d": 786,
#     "analytics_90d": 2511,
#     "analytics_365d": 10050
#   },
#   {
#     "pkg_name": "zboy",
#     "description": "GameBoy emulator",
#     "analytics_30d": 2,
#     "analytics_90d": 14,
#     "analytics_365d": 73
#   },
#   {
#     "pkg_name": "zdelta",
#     "description": "Lossless delta compression library",
#     "analytics_30d": 1,
#     "analytics_90d": 1,
#     "analytics_365d": 10
#   },
#   {
#     "pkg_name": "zebra",
#     "description": "Information management system",
#     "analytics_30d": 1,
#     "analytics_90d": 8,
#     "analytics_365d": 62
#   },
#   {
#     "pkg_name": "zeek",
#     "description": "Network security monitor",
#     "analytics_30d": 298,
#     "analytics_90d": 935,
#     "analytics_365d": 1518
#   },
#   {
#     "pkg_name": "zelda-roth-se",
#     "description": "Zelda Return of the Hylian SE",
#     "analytics_30d": 2,
#     "analytics_90d": 11,
#     "analytics_365d": 147
#   },
#   {
#     "pkg_name": "zenity",
#     "description": "GTK+ dialog boxes for the command-line",
#     "analytics_30d": 531,
#     "analytics_90d": 1430,
#     "analytics_365d": 8865
#   },
#   {
#     "pkg_name": "zero-install",
#     "description": "Zero Install is a decentralised software installation system",
#     "analytics_30d": 38,
#     "analytics_90d": 67,
#     "analytics_365d": 174
#   },
#   {
#     "pkg_name": "zeromq",
#     "description": "High-performance, asynchronous messaging library",
#     "analytics_30d": 2448,
#     "analytics_90d": 7302,
#     "analytics_365d": 36873
#   },
#   {
#     "pkg_name": "zig",
#     "description": "Programming language designed for robustness, optimality, and clarity",
#     "analytics_30d": 367,
#     "analytics_90d": 523,
#     "analytics_365d": 1630
#   },
#   {
#     "pkg_name": "zile",
#     "description": "Text editor development kit",
#     "analytics_30d": 23,
#     "analytics_90d": 51,
#     "analytics_365d": 182
#   },
#   {
#     "pkg_name": "zim",
#     "description": "Graphical text editor used to maintain a collection of wiki pages",
#     "analytics_30d": 261,
#     "analytics_90d": 420,
#     "analytics_365d": 2021
#   },
#   {
#     "pkg_name": "zimg",
#     "description": "Scaling, colorspace conversion, and dithering library",
#     "analytics_30d": 141,
#     "analytics_90d": 439,
#     "analytics_365d": 1336
#   },
#   {
#     "pkg_name": "zinc",
#     "description": "Stand-alone version of sbt's Scala incremental compiler",
#     "analytics_30d": 28,
#     "analytics_90d": 91,
#     "analytics_365d": 483
#   },
#   {
#     "pkg_name": "zint",
#     "description": "Barcode encoding library supporting over 50 symbologies",
#     "analytics_30d": 68,
#     "analytics_90d": 218,
#     "analytics_365d": 624
#   },
#   {
#     "pkg_name": "zip",
#     "description": "Compression and file packaging/archive utility",
#     "analytics_30d": 753,
#     "analytics_90d": 2097,
#     "analytics_365d": 7063
#   },
#   {
#     "pkg_name": "zita-convolver",
#     "description": "Fast, partitioned convolution engine library",
#     "analytics_30d": 8,
#     "analytics_90d": 13,
#     "analytics_365d": 61
#   },
#   {
#     "pkg_name": "zlib",
#     "description": "General-purpose lossless data-compression library",
#     "analytics_30d": 27366,
#     "analytics_90d": 76485,
#     "analytics_365d": 300035
#   },
#   {
#     "pkg_name": "zlog",
#     "description": "High-performance C logging library",
#     "analytics_30d": 3,
#     "analytics_90d": 7,
#     "analytics_365d": 41
#   },
#   {
#     "pkg_name": "zmap",
#     "description": "Network scanner for Internet-wide network studies",
#     "analytics_30d": 146,
#     "analytics_90d": 515,
#     "analytics_365d": 2024
#   },
#   {
#     "pkg_name": "zmqpp",
#     "description": "High-level C++ binding for zeromq",
#     "analytics_30d": 21,
#     "analytics_90d": 66,
#     "analytics_365d": 291
#   },
#   {
#     "pkg_name": "znapzend",
#     "description": "ZFS backup with remote capabilities and mbuffer integration",
#     "analytics_30d": 29,
#     "analytics_90d": 47,
#     "analytics_365d": 101
#   },
#   {
#     "pkg_name": "znc",
#     "description": "Advanced IRC bouncer",
#     "analytics_30d": 23,
#     "analytics_90d": 63,
#     "analytics_365d": 424
#   },
#   {
#     "pkg_name": "zola",
#     "description": "Fast static site generator in a single binary with everything built-in",
#     "analytics_30d": 289,
#     "analytics_90d": 953,
#     "analytics_365d": 2857
#   },
#   {
#     "pkg_name": "zookeeper",
#     "description": "Centralized server for distributed coordination of services",
#     "analytics_30d": 2517,
#     "analytics_90d": 6874,
#     "analytics_365d": 24681
#   },
#   {
#     "pkg_name": "zopfli",
#     "description": "New zlib (gzip, deflate) compatible compressor",
#     "analytics_30d": 343,
#     "analytics_90d": 2533,
#     "analytics_365d": 6910
#   },
#   {
#     "pkg_name": "zorba",
#     "description": "NoSQL query processor",
#     "analytics_30d": 31,
#     "analytics_90d": 35,
#     "analytics_365d": 135
#   },
#   {
#     "pkg_name": "zork",
#     "description": "The Dungeon modified from FORTRAN to C",
#     "analytics_30d": 38,
#     "analytics_90d": 123,
#     "analytics_365d": 576
#   },
#   {
#     "pkg_name": "zpaq",
#     "description": "Incremental, journaling command-line archiver",
#     "analytics_30d": 16,
#     "analytics_90d": 36,
#     "analytics_365d": 159
#   },
#   {
#     "pkg_name": "zplug",
#     "description": "The next-generation plugin manager for zsh",
#     "analytics_30d": 923,
#     "analytics_90d": 2754,
#     "analytics_365d": 10163
#   },
#   {
#     "pkg_name": "zrepl",
#     "description": "One-stop ZFS backup & replication solution",
#     "analytics_30d": 2,
#     "analytics_90d": 13,
#     "analytics_365d": 126
#   },
#   {
#     "pkg_name": "zsdx",
#     "description": "Zelda Mystery of Solarus DX",
#     "analytics_30d": 0,
#     "analytics_90d": 8,
#     "analytics_365d": 88
#   },
#   {
#     "pkg_name": "zsh",
#     "description": "UNIX shell (command interpreter)",
#     "analytics_30d": 42182,
#     "analytics_90d": 146229,
#     "analytics_365d": 494714
#   },
#   {
#     "pkg_name": "zsh-autosuggestions",
#     "description": "Fish-like fast/unobtrusive autosuggestions for zsh",
#     "analytics_30d": 4145,
#     "analytics_90d": 14337,
#     "analytics_365d": 58656
#   },
#   {
#     "pkg_name": "zsh-completions",
#     "description": "Additional completion definitions for zsh",
#     "analytics_30d": 10047,
#     "analytics_90d": 31599,
#     "analytics_365d": 160586
#   },
#   {
#     "pkg_name": "zsh-git-prompt",
#     "description": "Informative git prompt for zsh",
#     "analytics_30d": 388,
#     "analytics_90d": 1101,
#     "analytics_365d": 3819
#   },
#   {
#     "pkg_name": "zsh-history-substring-search",
#     "description": "Zsh port of Fish shell's history search",
#     "analytics_30d": 735,
#     "analytics_90d": 1923,
#     "analytics_365d": 6903
#   },
#   {
#     "pkg_name": "zsh-lovers",
#     "description": "Tips, tricks, and examples for zsh",
#     "analytics_30d": 127,
#     "analytics_90d": 316,
#     "analytics_365d": 1147
#   },
#   {
#     "pkg_name": "zsh-navigation-tools",
#     "description": "Zsh curses-based tools, e.g. multi-word history searcher",
#     "analytics_30d": 140,
#     "analytics_90d": 404,
#     "analytics_365d": 1569
#   },
#   {
#     "pkg_name": "zsh-syntax-highlighting",
#     "description": "Fish shell like syntax highlighting for zsh",
#     "analytics_30d": 14548,
#     "analytics_90d": 42682,
#     "analytics_365d": 129359
#   },
#   {
#     "pkg_name": "zshdb",
#     "description": "Debugger for zsh",
#     "analytics_30d": 104,
#     "analytics_90d": 376,
#     "analytics_365d": 1101
#   },
#   {
#     "pkg_name": "zssh",
#     "description": "Interactive file transfers over SSH",
#     "analytics_30d": 103,
#     "analytics_90d": 281,
#     "analytics_365d": 1350
#   },
#   {
#     "pkg_name": "zstd",
#     "description": "Zstandard is a real-time compression algorithm",
#     "analytics_30d": 904,
#     "analytics_90d": 2742,
#     "analytics_365d": 15642
#   },
#   {
#     "pkg_name": "zsxd",
#     "description": "Zelda Mystery of Solarus XD",
#     "analytics_30d": 1,
#     "analytics_90d": 10,
#     "analytics_365d": 95
#   },
#   {
#     "pkg_name": "zsync",
#     "description": "File transfer program",
#     "analytics_30d": 35,
#     "analytics_90d": 113,
#     "analytics_365d": 361
#   },
#   {
#     "pkg_name": "zurl",
#     "description": "HTTP and WebSocket client worker with ZeroMQ interface",
#     "analytics_30d": 20,
#     "analytics_90d": 32,
#     "analytics_365d": 125
#   },
#   {
#     "pkg_name": "zxcc",
#     "description": "CP/M 2/3 emulator for cross-compiling and CP/M tools under UNIX",
#     "analytics_30d": 0,
#     "analytics_90d": 4,
#     "analytics_365d": 34
#   },
#   {
#     "pkg_name": "zydis",
#     "description": "Fast and lightweight x86/x86_64 disassembler library",
#     "analytics_30d": 1,
#     "analytics_90d": 13,
#     "analytics_365d": 46
#   },
#   {
#     "pkg_name": "zyre",
#     "description": "Local Area Clustering for Peer-to-Peer Applications",
#     "analytics_30d": 4,
#     "analytics_90d": 15,
#     "analytics_365d": 84
#   },
#   {
#     "pkg_name": "zzuf",
#     "description": "Transparent application input fuzzer",
#     "analytics_30d": 5,
#     "analytics_90d": 25,
#     "analytics_365d": 88
#   },
#   {
#     "pkg_name": "zzz",
#     "description": "Command-line tool to put Macs to sleep",
#     "analytics_30d": 17,
#     "analytics_90d": 99,
#     "analytics_365d": 408
#   }
# ]

# %% [markdown]
# ## write the data of packages in to csv file

# %%
import csv

header = ['pkg_name','description','analytics_30d','analytics_90d','analytics_365d']
# create a new file for writing the details in csv format
# NOTE: you need to use encoding='utf-8', else some entries will fail and when we try to open
#       it fails with  message 'file not properly utf-8 encoded'
with open('package_analytics.csv','w', encoding="utf8") as csv_file:
    pkg_writer = csv.DictWriter(csv_file, fieldnames=header)
    pkg_writer.writeheader()
    for pkg in pkg_data:
        try:
            pkg_writer.writerow(pkg)
        except UnicodeEncodeError as err:
            print(f'{err} observed during {pkg}')
            continue
            
# when used encoding technique in file writing , solved some of the errors which could be seen entries being added to cvs file

# %% [markdown]
# ## Now we need to parse the csv using pandas and determine the needed statistics

# %%
import pandas as pd

pkg_df = pd.read_csv('package_analytics.csv')
pkg_df.head()
# Out:
#   pkg_name                                        description  analytics_30d  \
# 0     a2ps                           Any-to-PostScript filter             82
# 1   a52dec  Library for decoding ATSC A/52 streams (AKA 'A...             20
# 2  aacgain                  AAC-supporting version of mp3gain             54
# 3    aalib                Portable ASCII art graphics library             60
# 4   aamath      Renders mathematical expressions as ASCII art             17
#
#    analytics_90d  analytics_365d
# 0            324            1145
# 1             85             346
# 2            149             557
# 3            197             867
# 4             59             221
